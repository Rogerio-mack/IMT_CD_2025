# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2025/blob/main/Ex_who1_solucao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercício: WHO World Health Organization**
#
# Explore a página
#
# https://www.who.int/teams/global-tuberculosis-programme/data
#
# Entenda como os dados de tuberculose podem ser encontrados e seus metadados. Descubra, então, se os casos e mortes por tuberculose no Brasil vem sendo descrescentes.

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('https://extranet.who.int/tme/generateCSV.asp?ds=estimates')
df.head()
# Out:
#        country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0  Afghanistan   AF  AFG            4         EMR  2000   20130323
# 1  Afghanistan   AF  AFG            4         EMR  2001   20284311
# 2  Afghanistan   AF  AFG            4         EMR  2002   21378110
# 3  Afghanistan   AF  AFG            4         EMR  2003   22733047
# 4  Afghanistan   AF  AFG            4         EMR  2004   23560660
#
#    e_inc_100k  e_inc_100k_lo  e_inc_100k_hi  e_inc_num  e_inc_num_lo  \
# 0       190.0          122.0          271.0      38000         25000
# 1       189.0          122.0          271.0      38000         25000
# 2       189.0          122.0          270.0      40000         26000
# 3       189.0          122.0          270.0      43000         28000
# 4       189.0          122.0          270.0      44000         29000
#
#    e_inc_num_hi  e_tbhiv_prct  e_tbhiv_prct_lo  e_tbhiv_prct_hi  \
# 0         55000          0.02              0.0             0.05
# ...

# %%
# !wget https://extranet.who.int/tme/generateCSV.asp?ds=dictionary -O dictionary.csv
# Out:
# --2025-03-12 18:02:56--  https://extranet.who.int/tme/generateCSV.asp?ds=dictionary
# Resolving extranet.who.int (extranet.who.int)... 158.232.12.136
# Connecting to extranet.who.int (extranet.who.int)|158.232.12.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘dictionary.csv’
#
# dictionary.csv          [       <=>          ] 104.11K  61.8KB/s    in 1.7s
#
# 2025-03-12 18:03:00 (61.8 KB/s) - ‘dictionary.csv’ saved [106605]

# %%
dictionary = pd.read_csv('dictionary.csv')
display(dictionary.head())
# Out:
#      variable_name dataset code_list  \
# 0  budget_cpp_dstb  Budget       NaN
# 1   budget_cpp_mdr  Budget       NaN
# 2   budget_cpp_tpt  Budget       NaN
# 3   budget_cpp_xdr  Budget       NaN
# 4       budget_fld  Budget       NaN
#
#                                                                                                           definition
# 0  Average cost of drugs budgeted per patient for drug-susceptible TB treatment, excluding buffer stock (US Dollars)
# 1               Average cost of drugs budgeted per patient for MDR-TB treatment, excluding buffer stock (US Dollars)
# 2       Average cost of drugs budgeted per patient for  TB preventive treatment, excluding buffer stock (US Dollars)
# 3       Average cost of drugs budgeted per patient for pre-XDR/XDR-TB treatment, excluding buffer stock (US Dollars)
# 4                                                Budget required for drugs to treat drug-susceptible TB (US Dollars)

# %%
display(dictionary[dic.variable_name.str.contains('mort')])
# Out:
#                 variable_name    dataset code_list  \
# 167               e_mort_100k  Estimates       NaN
# 168            e_mort_100k_hi  Estimates       NaN
# 169            e_mort_100k_lo  Estimates       NaN
# 170     e_mort_exc_tbhiv_100k  Estimates       NaN
# 171  e_mort_exc_tbhiv_100k_hi  Estimates       NaN
# 172  e_mort_exc_tbhiv_100k_lo  Estimates       NaN
# 173      e_mort_exc_tbhiv_num  Estimates       NaN
# 174   e_mort_exc_tbhiv_num_hi  Estimates       NaN
# 175   e_mort_exc_tbhiv_num_lo  Estimates       NaN
# 176                e_mort_num  Estimates       NaN
# 177             e_mort_num_hi  Estimates       NaN
# 178             e_mort_num_lo  Estimates       NaN
# 179         e_mort_tbhiv_100k  Estimates       NaN
# 180      e_mort_tbhiv_100k_hi  Estimates       NaN
# 181      e_mort_tbhiv_100k_lo  Estimates       NaN
# 182          e_mort_tbhiv_num  Estimates       NaN
# 183       e_mort_tbhiv_num_hi  Estimates       NaN
# ...

# %%
df[df.country == 'Brazil'][['year','e_inc_num','e_mort_num']]
# Out:
#      year  e_inc_num  e_mort_num
# 648  2000      89000      8700.0
# 649  2001      85000      8200.0
# 650  2002      93000      7800.0
# 651  2003      96000      7600.0
# 652  2004      99000      7600.0
# 653  2005      92000      7100.0
# 654  2006      86000      7000.0
# 655  2007      86000      6900.0
# 656  2008      88000      7100.0
# 657  2009      87000      7000.0
# 658  2010      86000      8100.0
# 659  2011      87000      7900.0
# 660  2012      87000      7700.0
# 661  2013      88000      7700.0
# 662  2014      86000      7400.0
# 663  2015      86000      7200.0
# 664  2016      86000      7000.0
# 665  2017      91000      7100.0
# 666  2018      94000      6900.0
# 667  2019      94000      6900.0
# 668  2020      95000      7500.0
# 669  2021     102000      9000.0
# 670  2022     103000     13000.0
# 671  2023     103000     13000.0

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(df[df.country == 'Brazil'][['year']],df[df.country == 'Brazil'][['e_inc_num']],label='cases')
ax2.plot(df[df.country == 'Brazil'][['year']],df[df.country == 'Brazil'][['e_mort_num']],'r',label='deaths')

plt.title('Cases vs Deaths in Brazil')
plt.xlabel('Year')
ax1.set_ylabel('Cases')
ax2.set_ylabel('Deaths')
fig.legend()
plt.show()
