# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2025/blob/main/IMT_plot_evolucao_ex1_solucao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://github.com/Rogerio-mack/IMT_CD_2025/raw/refs/heads/main/data/economy.csv')
df.head()
# Out:
#   location_key       gdp_usd  gdp_per_capita_usd  human_capital_index
# 0           AD  3.154058e+09             40886.0                  NaN
# 1           AE  4.211423e+11             43103.0                0.659
# 2           AF  1.910135e+10               502.0                0.389
# 3           AG  1.727759e+09             17790.0                  NaN
# 4           AL  1.527808e+10              5352.0                0.621

# %% [markdown]
# # Exercício 1
#
# Faça um gráfico o mais similar possível do gráfico abaixo. Use 100 bins.
#
# Dicas:
# 1. `h.patches[0].get_height()`, para obter a altura de uma barra
# 2. `ax.get_xlim()`, para obter as dimensões de um gráfico

# %%
fig, ax = plt.subplots(figsize=(7, 4))

h = sns.histplot(df['gdp_usd'], kde=True, label='gdp_usd', ax=ax, alpha=0.5, bins=100)

# Customize the plot
ax.set_xlabel("GDP")
ax.set_ylabel("Countries")
ax.set_title("GDP Distribution",fontsize=14,weight='bold')
ax.set_xlim([0,df['gdp_usd'].quantile(0.98)])
ax.vlines(df['gdp_usd'].quantile(0.8),0,h.patches[0].get_height(),color=(0.6, 0.0, 0.0),linestyles='--')

ax.legend()

xmin, xmax = ax.get_xlim()
ymin, ymax = ax.get_ylim()

plt.annotate('80% dos países, GDP $\leq$ ' + str(np.round(df['gdp_usd'].quantile(0.8)/1000000,2)) + 'MM',
             xy=(df['gdp_usd'].quantile(0.8), h.patches[0].get_height()/2),                # ponto do gráfico
             xytext=((xmax - xmin)/6,2/3*(ymax - ymin)),           # posição do texto
             arrowprops=dict(arrowstyle="->"),
             weight='bold')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 4))

h = sns.histplot(df['gdp_usd'], kde=True, label='gdp_usd', ax=ax, alpha=0.5, bins=100)

# Customize the plot
ax.set_xlabel("GDP")
ax.set_ylabel("Countries")
ax.set_title("GDP Distribution",fontsize=14,weight='bold')
ax.set_xlim([0,df['gdp_usd'].quantile(0.98)])
ax.vlines(df['gdp_usd'].quantile(0.8),0,h.patches[0].get_height(),color=(0.6, 0.0, 0.0),linestyles='--')

ax.legend()

xmin, xmax = ax.get_xlim()
ymin, ymax = ax.get_ylim()

plt.annotate('80% dos países, GDP $\leq$ ' + str(np.round(df['gdp_usd'].quantile(0.8)/1000000,2)) + 'MM',
             xy=(df['gdp_usd'].quantile(0.8), h.patches[0].get_height()/2),                # ponto do gráfico
             xytext=((xmax - xmin)/6,2/3*(ymax - ymin)),           # posição do texto
             arrowprops=dict(arrowstyle="->"),
             weight='bold')

plt.annotate('altura 2/3 horizontal 1/6',
             xy=((xmax - xmin)/6,2/3*(ymax - ymin)),                # ponto do gráfico
             xytext=(2*(xmax - xmin)/6,1/3*(ymax - ymin)),           # posição do texto
             arrowprops=dict(arrowstyle="->",color='red'),
             color='red')

plt.annotate('altura 1/2',
             xy=(df['gdp_usd'].quantile(0.8), h.patches[0].get_height()/2),                # ponto do gráfico
             xytext=(2*(xmax - xmin)/6,1/5*(ymax - ymin)),           # posição do texto
             arrowprops=dict(arrowstyle="->",color='red'),
             color='red')

plt.annotate('percentil 0.98',
             xy=(xmax, ymin),                # ponto do gráfico
             xytext=(3*(xmax - xmin)/6,1/8*(ymax - ymin)),           # posição do texto
             arrowprops=dict(arrowstyle="->",color='red'),
             color='red')

plt.annotate('altura da 1a barra',
             xy=(df['gdp_usd'].quantile(0.8), h.patches[0].get_height()),                # ponto do gráfico
             xytext=(1*(xmax - xmin)/6,7/8*(ymax - ymin)),           # posição do texto
             arrowprops=dict(arrowstyle="->",color='red'),
             color='red')

plt.show()
