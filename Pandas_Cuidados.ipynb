# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2025/blob/main/Pandas_Cuidados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
id(df)
# Out:
# 136538905105552

# %%
df2 = df

id(df), id(df2), id(df[['age','gender']])
# Out:
# (136538905105552, 136538905105552, 136537819032080)

# %%
df2 = df[['age','gender']]

id(df), id(df2)
# Out:
# (136538905105552, 136537815479184)

# %%
df2 = df[df.columns]

id(df), id(df2)
# Out:
# (136538905105552, 136537815828368)

# %%
df2 = df.copy()

id(df), id(df2)
# Out:
# (136538905105552, 136537824336848)

# %%
s = pd.Series([1,2,3,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s[1]
# Out:
# 2

# %%
s[1] = 9
s
# Out:
# 0    1
# 1    9
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df = pd.DataFrame({'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]})
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.a
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
df.a[1]
# Out:
# 2

# %%
df = pd.DataFrame({'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]})
df.a[1] = 9
df
# Out:
# <ipython-input-13-cde0fe36c9ff>:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.a[1] = 9
#    a  b  c
# 0  1  4  7
# 1  9  5  8
# 2  3  6  9

# %%
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  9  5  8
# 2  3  6  9

# %%
df2 = df

df2
# Out:
#    a  b  c
# 0  1  4  7
# 1  9  5  8
# 2  3  6  9

# %%
df2['d'] = 99
df2
# Out:
#    a  b  c   d
# 0  1  4  7  99
# 1  9  5  8  99
# 2  3  6  9  99

# %%
df
# Out:
#    a  b  c   d
# 0  1  4  7  99
# 1  9  5  8  99
# 2  3  6  9  99

# %%
df[df.a >= 1]['b'] = 99
df
# Out:
#    a  b  c   d
# 0  1  4  7  99
# 1  9  5  8  99
# 2  3  6  9  99

# %% [markdown]
# Neste exemplo, df[df['a'] > 1] retorna uma nova cópia do DataFrame filtrada, e em seguida você está tentando modificar a coluna 'b' dessa cópia. Como resultado, a modificação não afeta o DataFrame original.

# %% [markdown]
# Se não houver aviso lançado, como o "SettingWithCopyWarning", pode ser difícil perceber que as mudanças não estão sendo feitas como esperado.

# %%
df.loc[df['a'] >= 1, 'b'] = 99
df
# Out:
#    a   b  c   d
# 0  1  99  7  99
# 1  9  99  8  99
# 2  3  99  9  99

# %% [markdown]
# Utilize .loc para indexação e evite múltiplas indexações.
