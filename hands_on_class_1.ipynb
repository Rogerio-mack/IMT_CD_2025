# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2025/blob/main/hands_on_class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/carData/BEPS.csv')
df.head()
# Out:
#    rownames              vote  age  economic.cond.national  \
# 0         1  Liberal Democrat   43                       3
# 1         2            Labour   36                       4
# 2         3            Labour   35                       4
# 3         4            Labour   24                       4
# 4         5            Labour   41                       2
#
#    economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 0                        3      4      1        4       2
# 1                        4      4      4        4       5
# 2                        4      5      2        3       3
# 3                        2      2      1        3       4
# 4                        2      1      1        4       6
#
#    political.knowledge  gender
# 0                    2  female
# 1                    2    male
# 2                    2    male
# 3                    0  female
# 4                    2    male

# %% [markdown]
# # Explorando a estrutura

# %%
df.shape
# Out:
# (1525, 11)

# %%
len(df)
# Out:
# 1525

# %%
df.shape[0]
# Out:
# 1525

# %%
df.columns
# Out:
# Index(['rownames', 'vote', 'age', 'economic.cond.national',
#        'economic.cond.household', 'Blair', 'Hague', 'Kennedy', 'Europe',
#        'political.knowledge', 'gender'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 11

# %%
df.columns[5:8]
# Out:
# Index(['Blair', 'Hague', 'Kennedy'], dtype='object')

# %%
df.describe()
# Out:
#           rownames          age  economic.cond.national  \
# count  1525.000000  1525.000000             1525.000000
# mean    763.000000    54.182295                3.245902
# std     440.373894    15.711209                0.880969
# min       1.000000    24.000000                1.000000
# 25%     382.000000    41.000000                3.000000
# 50%     763.000000    53.000000                3.000000
# 75%    1144.000000    67.000000                4.000000
# max    1525.000000    93.000000                5.000000
#
#        economic.cond.household        Blair        Hague      Kennedy  \
# count              1525.000000  1525.000000  1525.000000  1525.000000
# mean                  3.140328     3.334426     2.746885     3.135082
# std                   0.929951     1.174824     1.230703     1.081997
# min                   1.000000     1.000000     1.000000     1.000000
# 25%                   3.000000     2.000000     2.000000     2.000000
# ...

# %%
df.describe(include='all')
# Out:
#            rownames    vote          age  economic.cond.national  \
# count   1525.000000    1525  1525.000000             1525.000000
# unique          NaN       3          NaN                     NaN
# top             NaN  Labour          NaN                     NaN
# freq            NaN     720          NaN                     NaN
# mean     763.000000     NaN    54.182295                3.245902
# std      440.373894     NaN    15.711209                0.880969
# min        1.000000     NaN    24.000000                1.000000
# 25%      382.000000     NaN    41.000000                3.000000
# 50%      763.000000     NaN    53.000000                3.000000
# 75%     1144.000000     NaN    67.000000                4.000000
# max     1525.000000     NaN    93.000000                5.000000
#
#         economic.cond.household        Blair        Hague      Kennedy  \
# count               1525.000000  1525.000000  1525.000000  1525.000000
# ...

# %%
df.dtypes
# Out:
# rownames                    int64
# vote                       object
# age                         int64
# economic.cond.national      int64
# economic.cond.household     int64
# Blair                       int64
# Hague                       int64
# Kennedy                     int64
# Europe                      int64
# political.knowledge         int64
# gender                     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   rownames                 1525 non-null   int64
#  1   vote                     1525 non-null   object
#  2   age                      1525 non-null   int64
#  3   economic.cond.national   1525 non-null   int64
#  4   economic.cond.household  1525 non-null   int64
#  5   Blair                    1525 non-null   int64
#  6   Hague                    1525 non-null   int64
#  7   Kennedy                  1525 non-null   int64
#  8   Europe                   1525 non-null   int64
#  9   political.knowledge      1525 non-null   int64
#  10  gender                   1525 non-null   object
# dtypes: int64(9), object(2)
# memory usage: 131.2+ KB

# %%
df.isnull()
# Out:
#       rownames   vote    age  economic.cond.national  economic.cond.household  \
# 0        False  False  False                   False                    False
# 1        False  False  False                   False                    False
# 2        False  False  False                   False                    False
# 3        False  False  False                   False                    False
# 4        False  False  False                   False                    False
# ...        ...    ...    ...                     ...                      ...
# 1520     False  False  False                   False                    False
# 1521     False  False  False                   False                    False
# 1522     False  False  False                   False                    False
# 1523     False  False  False                   False                    False
# 1524     False  False  False                   False                    False
#
# ...

# %%
df.isnull().sum()
# Out:
# rownames                   0
# vote                       0
# age                        0
# economic.cond.national     0
# economic.cond.household    0
# Blair                      0
# Hague                      0
# Kennedy                    0
# Europe                     0
# political.knowledge        0
# gender                     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Seleções de dados

# %% [markdown]
# ## Seleção de colunas

# %%
df.columns
# Out:
# Index(['rownames', 'vote', 'age', 'economic.cond.national',
#        'economic.cond.household', 'Blair', 'Hague', 'Kennedy', 'Europe',
#        'political.knowledge', 'gender'],
#       dtype='object')

# %% [markdown]
# ### Seleção de uma coluna

# %%
df.vote
# Out:
# 0       Liberal Democrat
# 1                 Labour
# 2                 Labour
# 3                 Labour
# 4                 Labour
#               ...
# 1520        Conservative
# 1521        Conservative
# 1522              Labour
# 1523        Conservative
# 1524        Conservative
# Name: vote, Length: 1525, dtype: object

# %%
df['vote']
# Out:
# 0       Liberal Democrat
# 1                 Labour
# 2                 Labour
# 3                 Labour
# 4                 Labour
#               ...
# 1520        Conservative
# 1521        Conservative
# 1522              Labour
# 1523        Conservative
# 1524        Conservative
# Name: vote, Length: 1525, dtype: object

# %%
selecao = ['vote']

df[ selecao ]
# Out:
#                   vote
# 0     Liberal Democrat
# 1               Labour
# 2               Labour
# 3               Labour
# 4               Labour
# ...                ...
# 1520      Conservative
# 1521      Conservative
# 1522            Labour
# 1523      Conservative
# 1524      Conservative
#
# [1525 rows x 1 columns]

# %%
print(df['vote'])
# Out:
# 0       Liberal Democrat
# 1                 Labour
# 2                 Labour
# 3                 Labour
# 4                 Labour
#               ...
# 1520        Conservative
# 1521        Conservative
# 1522              Labour
# 1523        Conservative
# 1524        Conservative
# Name: vote, Length: 1525, dtype: object

# %%
type(df['vote'])
# Out:
# pandas.core.series.Series

# %%
print(df[['vote']])
# Out:
#                   vote
# 0     Liberal Democrat
# 1               Labour
# 2               Labour
# 3               Labour
# 4               Labour
# ...                ...
# 1520      Conservative
# 1521      Conservative
# 1522            Labour
# 1523      Conservative
# 1524      Conservative
#
# [1525 rows x 1 columns]

# %%
type(df[['vote']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['vote']
# Out:
# count       1525
# unique         3
# top       Labour
# freq         720
# Name: vote, dtype: object

# %%
df[['vote']]
# Out:
#                   vote
# 0     Liberal Democrat
# 1               Labour
# 2               Labour
# 3               Labour
# 4               Labour
# ...                ...
# 1520      Conservative
# 1521      Conservative
# 1522            Labour
# 1523      Conservative
# 1524      Conservative
#
# [1525 rows x 1 columns]

# %%
df.vote.value_counts()
# Out:
# vote
# Labour              720
# Conservative        462
# Liberal Democrat    343
# Name: count, dtype: int64

# %%
df.age.mean(), df['age'].min(), df[['age']].quantile(.9)
# Out:
# (54.18229508196721,
#  24,
#  age    75.0
#  Name: 0.9, dtype: float64)

# %% [markdown]
# # Seleção de várias colunas

# %%
df[ ['vote', 'age', 'gender'] ]
# Out:
#                   vote  age  gender
# 0     Liberal Democrat   43  female
# 1               Labour   36    male
# 2               Labour   35    male
# 3               Labour   24  female
# 4               Labour   41    male
# ...                ...  ...     ...
# 1520      Conservative   67    male
# 1521      Conservative   73    male
# 1522            Labour   37    male
# 1523      Conservative   61    male
# 1524      Conservative   74  female
#
# [1525 rows x 3 columns]

# %%
df[ ['vote', 'age', 'gender'] ].head()
# Out:
#                vote  age  gender
# 0  Liberal Democrat   43  female
# 1            Labour   36    male
# 2            Labour   35    male
# 3            Labour   24  female
# 4            Labour   41    male

# %%
df[ ['vote', 'age', 'gender'] ].describe(include='all')
# Out:
#           vote          age  gender
# count     1525  1525.000000    1525
# unique       3          NaN       2
# top     Labour          NaN  female
# freq       720          NaN     812
# mean       NaN    54.182295     NaN
# std        NaN    15.711209     NaN
# min        NaN    24.000000     NaN
# 25%        NaN    41.000000     NaN
# 50%        NaN    53.000000     NaN
# 75%        NaN    67.000000     NaN
# max        NaN    93.000000     NaN

# %%
my_df = df[ ['vote', 'age', 'gender'] ]

my_df.head()
# Out:
#                vote  age  gender
# 0  Liberal Democrat   43  female
# 1            Labour   36    male
# 2            Labour   35    male
# 3            Labour   24  female
# 4            Labour   41    male

# %%
df[[ 'Blair', 'Hague', 'Kennedy', 'Europe' ]].mean()
# Out:
# Blair      3.334426
# Hague      2.746885
# Kennedy    3.135082
# Europe     6.728525
# dtype: float64

# %% [markdown]
# # Seleção de linhas

# %%
df.gender.value_counts()
# Out:
# gender
# female    812
# male      713
# Name: count, dtype: int64

# %%
df[ df.gender == 'female' ]
# Out:
#       rownames              vote  age  economic.cond.national  \
# 0            1  Liberal Democrat   43                       3
# 3            4            Labour   24                       4
# 8            9            Labour   39                       3
# 10          11            Labour   39                       3
# 12          13            Labour   59                       4
# ...        ...               ...  ...                     ...
# 1509      1510            Labour   67                       3
# 1511      1512            Labour   63                       3
# 1514      1515            Labour   74                       3
# 1515      1516      Conservative   82                       2
# 1524      1525      Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 0                           3      4      1        4       2
# 3                           2      2      1        3       4
# ...

# %%
df[ (df.gender == 'female') & (df.age >= 60) ]
# Out:
#       rownames          vote  age  economic.cond.national  \
# 13          14        Labour   66                       3
# 14          15        Labour   77                       2
# 24          25  Conservative   60                       3
# 34          35  Conservative   76                       3
# 39          40  Conservative   72                       1
# ...        ...           ...  ...                     ...
# 1509      1510        Labour   67                       3
# 1511      1512        Labour   63                       3
# 1514      1515        Labour   74                       3
# 1515      1516  Conservative   82                       2
# 1524      1525  Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 13                          3      2      5        4       8
# 14                          3      2      1        4      11
# 24                          2      4      4        4       2
# ...

# %%
df.gender == 'female'
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1520    False
# 1521    False
# 1522    False
# 1523    False
# 1524     True
# Name: gender, Length: 1525, dtype: bool

# %%
selecao = (df.gender == 'female') & (df.age >= 60)

df[ selecao ]
# Out:
#       rownames          vote  age  economic.cond.national  \
# 13          14        Labour   66                       3
# 14          15        Labour   77                       2
# 24          25  Conservative   60                       3
# 34          35  Conservative   76                       3
# 39          40  Conservative   72                       1
# ...        ...           ...  ...                     ...
# 1509      1510        Labour   67                       3
# 1511      1512        Labour   63                       3
# 1514      1515        Labour   74                       3
# 1515      1516  Conservative   82                       2
# 1524      1525  Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 13                          3      2      5        4       8
# 14                          3      2      1        4      11
# 24                          2      4      4        4       2
# ...

# %%
df[ selecao ].head()
# Out:
#     rownames          vote  age  economic.cond.national  \
# 13        14        Labour   66                       3
# 14        15        Labour   77                       2
# 24        25  Conservative   60                       3
# 34        35  Conservative   76                       3
# 39        40  Conservative   72                       1
#
#     economic.cond.household  Blair  Hague  Kennedy  Europe  \
# 13                        3      2      5        4       8
# 14                        3      2      1        4      11
# 24                        2      4      4        4       2
# 34                        4      4      4        4       3
# 39                        3      2      2        2      11
#
#     political.knowledge  gender
# 13                    0  female
# 14                    2  female
# 24                    2  female
# 34                    2  female
# 39                    2  female

# %% [markdown]
# # Seleção de Linhas e Colunas

# %%
df[ (df.gender == 'female') & (df.age >= 60) ][ ['vote', 'age', 'gender'] ]
# Out:
#               vote  age  gender
# 13          Labour   66  female
# 14          Labour   77  female
# 24    Conservative   60  female
# 34    Conservative   76  female
# 39    Conservative   72  female
# ...            ...  ...     ...
# 1509        Labour   67  female
# 1511        Labour   63  female
# 1514        Labour   74  female
# 1515  Conservative   82  female
# 1524  Conservative   74  female
#
# [313 rows x 3 columns]

# %% [markdown]
# # Percentuais

# %%
len( df[ df.gender == 'male' ] ) / len(df)
# Out:
# 0.4675409836065574

# %%
df.gender.value_counts() / len(df)
# Out:
# gender
# female    0.532459
# male      0.467541
# Name: count, dtype: float64

# %%
df.groupby('gender').gender.count() /len(df)
# Out:
# gender
# female    0.532459
# male      0.467541
# Name: gender, dtype: float64
