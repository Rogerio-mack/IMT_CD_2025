# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2025/blob/main/Ex2_pandas_T1_2025_solucao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="ITM">
# </head>
#
# <img src="https://maua.br/images/selo-60-anos-maua.svg" width=300, align="right">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %%
#@markdown Nome completo e RA (*\<nome\>, \<RA\>*)
Aluno = 'Daniel Henrique, 1115665' #@param {type:"string"}

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# # **CASE: Gapminder**

# %%
coal_eletricity = pd.read_csv('https://github.com/open-numbers/ddf--bp--energy/raw/master/ddf--datapoints--coal_electricity_generation_twh--by--geo--year.csv')
coal_eletricity.head()
# Out:
#          geo  year  coal_electricity_generation_twh
# 0  argentina  1985                            0.607
# 1  argentina  1986                            1.013
# 2  argentina  1987                            1.016
# 3  argentina  1988                            1.586
# 4  argentina  1989                            0.865

# %% [markdown]
# # Q1.
#
# Considere os dados de `coal_eletricity`. Reorganize os dados como abaixo selecionando somente dados de 2011 em diante. Salve o resultado em um dataframe `coal_horiz`. Faça uma solução sem laços de programa.

# %%
coal_horiz = coal_eletricity[coal_eletricity.year>2010].groupby(['geo','year'])['coal_electricity_generation_twh'].mean().unstack()
display(coal_horiz.head())
# Out:
# year              2011         2012         2013         2014         2015  \
# geo
# argentina     2.911000     2.644000     2.378000     2.544000     2.387000
# australia   171.984500   165.384150   155.447400   155.229150   162.176163
# brazil       13.152318    14.754070    22.310656    27.290199    27.403555
# canada       77.624731    67.491398    68.592473    66.224731    62.118280
# china      3690.866100  3748.194311  4077.366742  4203.058790  4046.167660
#
# year              2016         2017         2018         2019
# geo
# argentina     1.930307     2.112000     2.105000     0.710430
# australia   162.322408   159.141258   156.544522   149.495780
# brazil       26.128519    25.766995    23.660047    25.729413
# canada       62.261290    60.126882    50.574194    54.605425
# china      4156.350123  4430.029738  4765.047799  4853.716920

# %%
coal_horiz = coal_eletricity[coal_eletricity.year>2010].pivot_table('coal_electricity_generation_twh', index='geo',columns='year',observed=True)
display(coal_horiz.head())
# Out:
# year              2011         2012         2013         2014         2015  \
# geo
# argentina     2.911000     2.644000     2.378000     2.544000     2.387000
# australia   171.984500   165.384150   155.447400   155.229150   162.176163
# brazil       13.152318    14.754070    22.310656    27.290199    27.403555
# canada       77.624731    67.491398    68.592473    66.224731    62.118280
# china      3690.866100  3748.194311  4077.366742  4203.058790  4046.167660
#
# year              2016         2017         2018         2019
# geo
# argentina     1.930307     2.112000     2.105000     0.710430
# australia   162.322408   159.141258   156.544522   149.495780
# brazil       26.128519    25.766995    23.660047    25.729413
# canada       62.261290    60.126882    50.574194    54.605425
# china      4156.350123  4430.029738  4765.047799  4853.716920

# %%
coal_horiz = coal_eletricity[coal_eletricity.year>2010].pivot(index='geo' ,columns='year', values='coal_electricity_generation_twh')
display(coal_horiz.head())
# Out:
# year              2011         2012         2013         2014         2015  \
# geo
# argentina     2.911000     2.644000     2.378000     2.544000     2.387000
# australia   171.984500   165.384150   155.447400   155.229150   162.176163
# brazil       13.152318    14.754070    22.310656    27.290199    27.403555
# canada       77.624731    67.491398    68.592473    66.224731    62.118280
# china      3690.866100  3748.194311  4077.366742  4203.058790  4046.167660
#
# year              2016         2017         2018         2019
# geo
# argentina     1.930307     2.112000     2.105000     0.710430
# australia   162.322408   159.141258   156.544522   149.495780
# brazil       26.128519    25.766995    23.660047    25.729413
# canada       62.261290    60.126882    50.574194    54.605425
# china      4156.350123  4430.029738  4765.047799  4853.716920

# %%
#@markdown sanity check
print(coal_horiz.shape == (44, 9))
print(coal_horiz.loc['brazil'].sum() == 206.19577071999998)
# Out:
# True
# True

# %% [markdown]
# Responda em Q1 com o valor da soma abaixo em:

# %%
random.seed(1)
int(coal_horiz.iloc[random.sample(range(len(coal_horiz)), 10)].sum().sum())
# Out:
# 110522

# %% [markdown]
# # Q2.
#
# Considere os dados de `coal_eletricity`. Crie para cada localização geográfica (`geo`) os valores 'all' e 'mean' com a soma e média de valores de todos os anos como abaixo. Salve o resultado em um dataframe `coal_verti`. Elabore uma solução sem laços de programa.

# %%
coal_horiz = coal_eletricity.pivot_table('coal_electricity_generation_twh', index='geo',columns='year',observed=True)
coal_horiz['mean'] = coal_horiz.mean(axis=1)
coal_horiz['all'] = coal_horiz.drop(columns='mean').sum(axis=1)
coal_verti = coal_horiz.reset_index().melt(id_vars='geo',value_vars=coal_horiz.columns).sort_values('geo').reset_index(drop=True)
coal_verti.columns = coal_eletricity.columns
coal_verti = coal_verti.sort_values(['geo','year']).reset_index(drop=True)

display(coal_verti)
# Out:
#             geo  year  coal_electricity_generation_twh
# 0     argentina  1985                         0.607000
# 1     argentina  1986                         1.013000
# 2     argentina  1987                         1.016000
# 3     argentina  1988                         1.586000
# 4     argentina  1989                         0.865000
# ...         ...   ...                              ...
# 1623    vietnam  2017                        62.538700
# 1624    vietnam  2018                        83.900960
# 1625    vietnam  2019                       112.527968
# 1626    vietnam   all                       611.788405
# 1627    vietnam  mean                        17.479669
#
# [1628 rows x 3 columns]

# %%
#@markdown sanity check
print(coal_verti.shape == (1628, 3))
# Out:
# True

# %% [markdown]
# Responda em Q2 com o valor da soma abaixo em:

# %%
random.seed(1)
int(coal_verti.loc[random.sample(range(len(coal_verti)), 10)].coal_electricity_generation_twh.sum())
# Out:
# 7319

# %% [markdown]
# # Q3.
#
# Considere os dados de `coal_eletricity`. Determine qual país teve a maior produção de energia elétrica por carvão a cada ano. Note que os dados possuem valores totais por região e podem precisar serem excluídos. Elabore uma solução sem laços de programa.
#
# **Dica.** Você pode achar útil empregar o comando [`idxmax`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html)

# %%
coal_eletricity = coal_eletricity.loc[ ~coal_eletricity.geo.isin([ x for x in coal_eletricity.geo if 'total' in x ])]
coal_eletricity.groupby(['geo','year'])['coal_electricity_generation_twh'].max().unstack().idxmax()
# Out:
# year
# 1985       us
# 1986       us
# 1987       us
# 1988       us
# 1989       us
# 1990       us
# 1991       us
# 1992       us
# 1993       us
# 1994       us
# 1995       us
# 1996       us
# 1997       us
# 1998       us
# 1999       us
# 2000       us
# 2001       us
# 2002       us
# 2003       us
# 2004       us
# 2005       us
# 2006    china
# 2007    china
# 2008    china
# 2009    china
# 2010    china
# 2011    china
# 2012    china
# 2013    china
# 2014    china
# 2015    china
# 2016    china
# 2017    china
# 2018    china
# 2019    china
# dtype: object

# %% [markdown]
# Responda em Q3 a lista dos maiores geradores no formato:
#
# ```
# <ano-inicial>:<ano-final>,<país1>;<ano-inicial>:<ano-final>,<país2>;...
# ```
#
# exemplo:
#
# **1895:1968,United Kingdom;1969:2001,USA;2002:2019,Brazil**

# %% [markdown]
# # Q4. Pareto 80/20
#
# Considere os dados de `coal_eletricity`. Considere os dados de `coal_eletricity`. **Encontre os maiores geradores em 2019 e determine o pequeno número de países responsáveis por 80% da geração mundial**. Note que os dados possuem valores totais por região que precisam ser excluídos. Você é livre para elaborar uma solução com ou sem laços de programa (sim, sem laço é possível).
#
# **Dica.** Você pode querer empregar o comando [`cumsum`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.cumsum.html)

# %%
coal_eletricity = coal_eletricity.loc[ ~coal_eletricity.geo.isin([ x for x in coal_eletricity.geo if 'total' in x ])]
coal_80 = coal_eletricity[ coal_eletricity.year == 2019 ].sort_values('coal_electricity_generation_twh',ascending=False)
coal_80 = coal_80.reset_index(drop=True)

coal_80['acum'] = coal_80[['coal_electricity_generation_twh']].cumsum() / coal_80['coal_electricity_generation_twh'].sum()
coal_80[ coal_80['acum'] < 0.82 ]
# Out:
#                   geo  year  coal_electricity_generation_twh      acum
# 0               china  2019                      4853.716920  0.494063
# 1               india  2019                      1137.368185  0.609837
# 2                  us  2019                      1053.529530  0.717076
# 3               japan  2019                       326.160961  0.750276
# 4         south_korea  2019                       238.718502  0.774576
# 5        south_africa  2019                       217.324215  0.796697
# 6  russian_federation  2019                       182.181675  0.815242

# %% [markdown]
# Nesta questão responda sobre os países maiores geradores de energia que correspondem a 80% da produção mundial dos países.

# %% [markdown]
# # Q5. Como se relacionam as emissões de CO2 e a geração de energia por carvão?
#
# Veja o exemplo de join a seguir. E você pode querer acessar a documentação do `Pandas` para uso do [`merge`](https://pandas.pydata.org/docs/reference/api/pandas.merge.html).

# %%
country_entities = pd.read_csv('https://github.com/open-numbers/ddf--gapminder--co2_emission/raw/master/ddf--entities--country.csv')
country_entities.head()
# Out:
#   country         name
# 0    abkh     Abkhazia
# 1     abw        Aruba
# 2     afg  Afghanistan
# 3     ago       Angola
# 4     aia     Anguilla

# %%
co2_emissions = pd.read_csv('https://github.com/open-numbers/ddf--gapminder--co2_emission/raw/master/ddf--datapoints--yearly_co2_emissions_1000_tonnes--by--country--year.csv')
co2_emissions.head()
# Out:
#   country  year  yearly_co2_emissions_1000_tonnes
# 0     abw  1959                         719.95990
# 1     abw  1960                         619.06729
# 2     abw  1961                         646.08113
# 3     abw  1962                         709.52273
# 4     abw  1963                         679.64379

# %%
co2_country = country_entities.merge(co2_emissions, how='inner', left_on='country', right_on='country')

# ou simplesmente,
# co2_country = country_entities.merge(co2_emissions)
# já que colunas de mesmo nome são automaticamente empregadas no join

co2_country
# Out:
#       country      name  year  yearly_co2_emissions_1000_tonnes
# 0         abw     Aruba  1959                         719.95990
# 1         abw     Aruba  1960                         619.06729
# 2         abw     Aruba  1961                         646.08113
# 3         abw     Aruba  1962                         709.52273
# 4         abw     Aruba  1963                         679.64379
# ...       ...       ...   ...                               ...
# 20606     zwe  Zimbabwe  2015                       12180.42531
# 20607     zwe  Zimbabwe  2016                       10823.61603
# 20608     zwe  Zimbabwe  2017                       10255.23103
# 20609     zwe  Zimbabwe  2018                       11349.86038
# 20610     zwe  Zimbabwe  2019                       10382.78115
#
# [20611 rows x 4 columns]

# %% [markdown]
# Empregue o exemplo anterior e o dataframe `coal_eletricity` para construir um conjunto de dados `co2_coal` como abaixo.

# %%
coal_eletricity = pd.read_csv('https://github.com/open-numbers/ddf--bp--energy/raw/master/ddf--datapoints--coal_electricity_generation_twh--by--geo--year.csv')
coal_eletricity.head()
# Out:
#          geo  year  coal_electricity_generation_twh
# 0  argentina  1985                            0.607
# 1  argentina  1986                            1.013
# 2  argentina  1987                            1.016
# 3  argentina  1988                            1.586
# 4  argentina  1989                            0.865

# %%
co2_country['name'] = co2_country['name'].str.lower()
co2_coal = co2_country.merge(coal_eletricity, how='inner', left_on=['name','year'], right_on=['geo','year'])

co2_coal = co2_coal.drop(columns=['geo'])
co2_coal
# Out:
#     country       name  year  yearly_co2_emissions_1000_tonnes  \
# 0       arg  argentina  1985                      100614.25470
# 1       arg  argentina  1986                      104236.26912
# 2       arg  argentina  1987                      114972.40710
# 3       arg  argentina  1988                      121505.28428
# 4       arg  argentina  1989                      117117.12341
# ..      ...        ...   ...                               ...
# 800     vnm    vietnam  2015                      184586.59931
# 801     vnm    vietnam  2016                      185584.00538
# 802     vnm    vietnam  2017                      182733.52483
# 803     vnm    vietnam  2018                      211947.52454
# 804     vnm    vietnam  2019                      247911.72979
#
#      coal_electricity_generation_twh
# 0                           0.607000
# 1                           1.013000
# 2                           1.016000
# 3                           1.586000
# ...

# %%
co2_coal[ co2_coal.country == 'us']
# Out:
# Empty DataFrame
# Columns: [country, name, year, yearly_co2_emissions_1000_tonnes, coal_electricity_generation_twh]
# Index: []

# %% [markdown]
# Note que os nomes dos países encontram-se em um formato diferente (lower/upper case) nos dataframes a serem empregados e você pode querer empregar a função [`str`](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.html) para ajustar isso. Você pode empregar somente os nomes que satisfizerem a junção interna.

# %% [markdown]
# Responda Q5 com a correlação abaixo.

# %%
np.round(co2_coal[['yearly_co2_emissions_1000_tonnes','coal_electricity_generation_twh']].corr().values[0,1],5)
# Out:
# np.float64(0.97876)

# %% [markdown]
# # Q6.
#
# Os Estados Unidos aparecem com um nome diferente nos dois dataframes empregados no exercício anterior. Ajuste para um único nome nos dois dataframes para que ele participe da junção. Refaça a junção criando o dataframe `co2_coal_with_us` e responda Q6 com a correlação abaixo.

# %%
co2_country
# Out:
#       country      name  year  yearly_co2_emissions_1000_tonnes
# 0         abw     aruba  1959                         719.95990
# 1         abw     aruba  1960                         619.06729
# 2         abw     aruba  1961                         646.08113
# 3         abw     aruba  1962                         709.52273
# 4         abw     aruba  1963                         679.64379
# ...       ...       ...   ...                               ...
# 20606     zwe  zimbabwe  2015                       12180.42531
# 20607     zwe  zimbabwe  2016                       10823.61603
# 20608     zwe  zimbabwe  2017                       10255.23103
# 20609     zwe  zimbabwe  2018                       11349.86038
# 20610     zwe  zimbabwe  2019                       10382.78115
#
# [20611 rows x 4 columns]

# %%
co2_country.loc[ co2_country.name == 'usa','name'] = 'us'
co2_country['name'] = co2_country['name'].str.lower()

co2_coal = co2_country.merge(coal_eletricity, how='inner', left_on=['name','year'], right_on=['geo','year'])

co2_coal = co2_coal.drop(columns=['geo'])
co2_coal
# Out:
#     country       name  year  yearly_co2_emissions_1000_tonnes  \
# 0       arg  argentina  1985                      100614.25470
# 1       arg  argentina  1986                      104236.26912
# 2       arg  argentina  1987                      114972.40710
# 3       arg  argentina  1988                      121505.28428
# 4       arg  argentina  1989                      117117.12341
# ..      ...        ...   ...                               ...
# 835     vnm    vietnam  2015                      184586.59931
# 836     vnm    vietnam  2016                      185584.00538
# 837     vnm    vietnam  2017                      182733.52483
# 838     vnm    vietnam  2018                      211947.52454
# 839     vnm    vietnam  2019                      247911.72979
#
#      coal_electricity_generation_twh
# 0                           0.607000
# 1                           1.013000
# 2                           1.016000
# 3                           1.586000
# ...

# %%
co2_coal[ co2_coal.name == 'us']
# Out:
#     country name  year  yearly_co2_emissions_1000_tonnes  \
# 770     usa   us  1985                      4.488010e+06
# 771     usa   us  1986                      4.491530e+06
# 772     usa   us  1987                      4.684667e+06
# 773     usa   us  1988                      4.889591e+06
# 774     usa   us  1989                      4.952072e+06
# 775     usa   us  1990                      5.132500e+06
# 776     usa   us  1991                      5.083048e+06
# 777     usa   us  1992                      5.186950e+06
# 778     usa   us  1993                      5.287764e+06
# 779     usa   us  1994                      5.381435e+06
# 780     usa   us  1995                      5.443359e+06
# 781     usa   us  1996                      5.631519e+06
# 782     usa   us  1997                      5.708377e+06
# 783     usa   us  1998                      5.755761e+06
# 784     usa   us  1999                      5.835071e+06
# ...

# %%
np.round(co2_coal[['yearly_co2_emissions_1000_tonnes','coal_electricity_generation_twh']].corr().values[0,1],5)
# Out:
# np.float64(0.97903)
