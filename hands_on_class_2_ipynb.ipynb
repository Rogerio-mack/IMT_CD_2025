# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_CD_2025/blob/main/hands_on_class_2_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/openintro/mlb_teams.csv')
df.head()
# Out:
#    rownames  year league_id division_id  rank  games_played  home_games  wins  \
# 0         1  1876        NL         NaN     4            70         NaN    39
# 1         2  1876        NL         NaN     1            66         NaN    52
# 2         3  1876        NL         NaN     8            65         NaN     9
# 3         4  1876        NL         NaN     2            69         NaN    47
# 4         5  1876        NL         NaN     5            69         NaN    30
#
#    losses division_winner  ... hits_allowed homeruns_allowed walks_allowed  \
# 0      31             NaN  ...          732                7           104
# 1      14             NaN  ...          608                6            29
# 2      56             NaN  ...          850                9            34
# 3      21             NaN  ...          570                2            27
# 4      36             NaN  ...          605                3            38
#
# ...

# %% [markdown]
# # Estrutura dos dados

# %%
df.shape
# Out:
# (2784, 42)

# %%
len(df)
# Out:
# 2784

# %%
df.shape[0]
# Out:
# 2784

# %%
df.dtypes
# Out:
# rownames                    int64
# year                        int64
# league_id                  object
# division_id                object
# rank                        int64
# games_played                int64
# home_games                float64
# wins                        int64
# losses                      int64
# division_winner            object
# wild_card_winner           object
# league_winner              object
# world_series_winner        object
# runs_scored                 int64
# at_bats                     int64
# hits                        int64
# doubles                     int64
# triples                     int64
# homeruns                    int64
# walks                       int64
# strikeouts_by_batters     float64
# stolen_bases              float64
# caught_stealing           float64
# batters_hit_by_pitch      float64
# sacrifice_flies           float64
# opponents_runs_scored       int64
# earned_runs_allowed         int64
# ...

# %%
df.describe()
# Out:
#           rownames         year         rank  games_played   home_games  \
# count  2784.000000  2784.000000  2784.000000   2784.000000  2556.000000
# mean   1392.500000  1962.717672     3.980963    153.118534    78.014476
# std     803.815899    39.800654     2.237914     18.201875     6.971355
# min       1.000000  1876.000000     1.000000     57.000000    24.000000
# 25%     696.750000  1930.000000     2.000000    154.000000    77.000000
# 50%    1392.500000  1970.000000     4.000000    161.000000    81.000000
# 75%    2088.250000  1997.000000     5.000000    162.000000    81.000000
# max    2784.000000  2020.000000    12.000000    165.000000    84.000000
#
#               wins       losses  runs_scored      at_bats         hits  ...  \
# count  2784.000000  2784.000000  2784.000000  2784.000000  2784.000000  ...
# mean     76.189296    76.189296   687.576509  5227.864583  1367.210848  ...
# std      15.909342    15.853321   126.206345   606.564336   185.892343  ...
# ...

# %%
df.describe(include='all')
# Out:
#            rownames         year league_id division_id         rank  \
# count   2784.000000  2784.000000      2784        1438  2784.000000
# unique          NaN          NaN         2           3          NaN
# top             NaN          NaN        NL           E          NaN
# freq            NaN          NaN      1504         588          NaN
# mean    1392.500000  1962.717672       NaN         NaN     3.980963
# std      803.815899    39.800654       NaN         NaN     2.237914
# min        1.000000  1876.000000       NaN         NaN     1.000000
# 25%      696.750000  1930.000000       NaN         NaN     2.000000
# 50%     1392.500000  1970.000000       NaN         NaN     4.000000
# 75%     2088.250000  1997.000000       NaN         NaN     5.000000
# max     2784.000000  2020.000000       NaN         NaN    12.000000
#
#         games_played   home_games         wins       losses division_winner  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2784 entries, 0 to 2783
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   rownames                2784 non-null   int64
#  1   year                    2784 non-null   int64
#  2   league_id               2784 non-null   object
#  3   division_id             1438 non-null   object
#  4   rank                    2784 non-null   int64
#  5   games_played            2784 non-null   int64
#  6   home_games              2556 non-null   float64
#  7   wins                    2784 non-null   int64
#  8   losses                  2784 non-null   int64
#  9   division_winner         1410 non-null   object
#  10  wild_card_winner        774 non-null    object
#  11  league_winner           2756 non-null   object
#  12  world_series_winner     2536 non-null   object
#  13  runs_scored             2784 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['rownames', 'year', 'league_id', 'division_id', 'rank', 'games_played',
#        'home_games', 'wins', 'losses', 'division_winner', 'wild_card_winner',
#        'league_winner', 'world_series_winner', 'runs_scored', 'at_bats',
#        'hits', 'doubles', 'triples', 'homeruns', 'walks',
#        'strikeouts_by_batters', 'stolen_bases', 'caught_stealing',
#        'batters_hit_by_pitch', 'sacrifice_flies', 'opponents_runs_scored',
#        'earned_runs_allowed', 'earned_run_average', 'complete_games',
#        'shutouts', 'saves', 'outs_pitches', 'hits_allowed', 'homeruns_allowed',
#        'walks_allowed', 'strikeouts_by_pitchers', 'errors', 'double_plays',
#        'fielding_percentage', 'team_name', 'ball_park', 'home_attendance'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 42

# %%
df.columns[5:10]
# Out:
# Index(['games_played', 'home_games', 'wins', 'losses', 'division_winner'], dtype='object')

# %%
df.isnull()
# Out:
#       rownames   year  league_id  division_id   rank  games_played  \
# 0        False  False      False         True  False         False
# 1        False  False      False         True  False         False
# 2        False  False      False         True  False         False
# 3        False  False      False         True  False         False
# 4        False  False      False         True  False         False
# ...        ...    ...        ...          ...    ...           ...
# 2779     False  False      False        False  False         False
# 2780     False  False      False        False  False         False
# 2781     False  False      False        False  False         False
# 2782     False  False      False        False  False         False
# 2783     False  False      False        False  False         False
#
#       home_games   wins  losses  division_winner  ...  hits_allowed  \
# 0           True  False   False             True  ...         False
# ...

# %%
df.isnull().sum()
# Out:
# rownames                     0
# year                         0
# league_id                    0
# division_id               1346
# rank                         0
# games_played                 0
# home_games                 228
# wins                         0
# losses                       0
# division_winner           1374
# wild_card_winner          2010
# league_winner               28
# world_series_winner        248
# runs_scored                  0
# at_bats                      0
# hits                         0
# doubles                      0
# triples                      0
# homeruns                     0
# walks                        0
# strikeouts_by_batters       16
# stolen_bases                76
# caught_stealing            708
# batters_hit_by_pitch      1066
# sacrifice_flies           1370
# opponents_runs_scored        0
# earned_runs_allowed          0
# earned_run_average           0
# complete_games               0
# shutouts                     0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 8578

# %% [markdown]
# # Seleções

# %% [markdown]
# ## Seleção de colunas, 1 coluna

# %% [markdown]
# ```
# df.team_name == df['team_name'] != df[['team-name']]
# ```

# %%
df.team_name
# Out:
# 0               Boston Red Caps
# 1       Chicago White Stockings
# 2               Cincinnati Reds
# 3           Hartford Dark Blues
# 4              Louisville Grays
#                  ...
# 2779        St. Louis Cardinals
# 2780             Tampa Bay Rays
# 2781              Texas Rangers
# 2782          Toronto Blue Jays
# 2783       Washington Nationals
# Name: team_name, Length: 2784, dtype: object

# %%
print(df['team_name'])
# Out:
# 0               Boston Red Caps
# 1       Chicago White Stockings
# 2               Cincinnati Reds
# 3           Hartford Dark Blues
# 4              Louisville Grays
#                  ...
# 2779        St. Louis Cardinals
# 2780             Tampa Bay Rays
# 2781              Texas Rangers
# 2782          Toronto Blue Jays
# 2783       Washington Nationals
# Name: team_name, Length: 2784, dtype: object

# %%
print(df[['team_name']])
# Out:
#                     team_name
# 0             Boston Red Caps
# 1     Chicago White Stockings
# 2             Cincinnati Reds
# 3         Hartford Dark Blues
# 4            Louisville Grays
# ...                       ...
# 2779      St. Louis Cardinals
# 2780           Tampa Bay Rays
# 2781            Texas Rangers
# 2782        Toronto Blue Jays
# 2783     Washington Nationals
#
# [2784 rows x 1 columns]

# %%
selecao = 'team_name'

df[selecao]
# Out:
# 0               Boston Red Caps
# 1       Chicago White Stockings
# 2               Cincinnati Reds
# 3           Hartford Dark Blues
# 4              Louisville Grays
#                  ...
# 2779        St. Louis Cardinals
# 2780             Tampa Bay Rays
# 2781              Texas Rangers
# 2782          Toronto Blue Jays
# 2783       Washington Nationals
# Name: team_name, Length: 2784, dtype: object

# %%
type(df['team_name'])
# Out:
# pandas.core.series.Series

# %%
type(df[['team_name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.wins.mean(), df['wins'].quantile(.9)
# Out:
# (76.1892959770115, 95.0)

# %%
df[['team_name']].value_counts()
# Out:
# team_name
# Cincinnati Reds          130
# Pittsburgh Pirates       130
# Philadelphia Phillies    129
# St. Louis Cardinals      121
# Chicago White Sox        120
#                         ...
# Seattle Pilots             1
# Cleveland Bronchos         1
# Milwaukee Grays            1
# Boston Rustlers            1
# St. Louis Perfectos        1
# Name: count, Length: 86, dtype: int64

# %% [markdown]
# ## Seleção de colunas, $n$ colunas

# %%
df[['team_name','wins','losses']]
# Out:
#                     team_name  wins  losses
# 0             Boston Red Caps    39      31
# 1     Chicago White Stockings    52      14
# 2             Cincinnati Reds     9      56
# 3         Hartford Dark Blues    47      21
# 4            Louisville Grays    30      36
# ...                       ...   ...     ...
# 2779      St. Louis Cardinals    30      28
# 2780           Tampa Bay Rays    40      20
# 2781            Texas Rangers    22      38
# 2782        Toronto Blue Jays    32      28
# 2783     Washington Nationals    26      34
#
# [2784 rows x 3 columns]

# %%
df[['team_name','wins','losses']].describe(include='all')
# Out:
#                  team_name         wins       losses
# count                 2784  2784.000000  2784.000000
# unique                  86          NaN          NaN
# top     Pittsburgh Pirates          NaN          NaN
# freq                   130          NaN          NaN
# mean                   NaN    76.189296    76.189296
# std                    NaN    15.909342    15.853321
# min                    NaN     9.000000    14.000000
# 25%                    NaN    67.000000    67.000000
# 50%                    NaN    78.000000    77.000000
# 75%                    NaN    88.000000    87.000000
# max                    NaN   116.000000   134.000000

# %%
df[['team_name','wins','losses']].head()
# Out:
#                  team_name  wins  losses
# 0          Boston Red Caps    39      31
# 1  Chicago White Stockings    52      14
# 2          Cincinnati Reds     9      56
# 3      Hartford Dark Blues    47      21
# 4         Louisville Grays    30      36

# %%
my_df = df[['team_name','wins','losses']]
my_df.head()
# Out:
#                  team_name  wins  losses
# 0          Boston Red Caps    39      31
# 1  Chicago White Stockings    52      14
# 2          Cincinnati Reds     9      56
# 3      Hartford Dark Blues    47      21
# 4         Louisville Grays    30      36

# %%
df[['wins','losses']].mean()
# Out:
# wins      76.189296
# losses    76.189296
# dtype: float64

# %% [markdown]
# ## Seleção de linhas

# %%
df[ df.team_name == 'Boston Red Sox' ]
# Out:
#       rownames  year league_id division_id  rank  games_played  home_games  \
# 340        341  1908        AL         NaN     5           155        77.0
# 356        357  1909        AL         NaN     3           152        75.0
# 372        373  1910        AL         NaN     4           158        80.0
# 388        389  1911        AL         NaN     4           153        76.0
# 404        405  1912        AL         NaN     1           154        78.0
# ...        ...   ...       ...         ...   ...           ...         ...
# 2637      2638  2016        AL           E     1           162        81.0
# 2667      2668  2017        AL           E     1           162        81.0
# 2697      2698  2018        AL           E     1           162        81.0
# 2727      2728  2019        AL           E     3           162        81.0
# 2757      2758  2020        AL           E     5            60        31.0
#
# ...

# %%
df[ (df.team_name == 'Boston Red Sox') & (df.year > 2015) ]
# Out:
#       rownames  year league_id division_id  rank  games_played  home_games  \
# 2637      2638  2016        AL           E     1           162        81.0
# 2667      2668  2017        AL           E     1           162        81.0
# 2697      2698  2018        AL           E     1           162        81.0
# 2727      2728  2019        AL           E     3           162        81.0
# 2757      2758  2020        AL           E     5            60        31.0
#
#       wins  losses division_winner  ... hits_allowed homeruns_allowed  \
# 2637    93      69               Y  ...         1342              176
# 2667    93      69               Y  ...         1384              195
# 2697   108      54               Y  ...         1305              176
# 2727    84      78               N  ...         1423              215
# 2757    24      36               N  ...          587               98
#
#      walks_allowed  strikeouts_by_pitchers  errors  double_plays  \
# ...

# %%
(df.team_name == 'Boston Red Sox')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2779    False
# 2780    False
# 2781    False
# 2782    False
# 2783    False
# Name: team_name, Length: 2784, dtype: bool

# %%
selecao = (df.team_name == 'Boston Red Sox') & (df.year > 2015)

df[selecao]
# Out:
#       rownames  year league_id division_id  rank  games_played  home_games  \
# 2637      2638  2016        AL           E     1           162        81.0
# 2667      2668  2017        AL           E     1           162        81.0
# 2697      2698  2018        AL           E     1           162        81.0
# 2727      2728  2019        AL           E     3           162        81.0
# 2757      2758  2020        AL           E     5            60        31.0
#
#       wins  losses division_winner  ... hits_allowed homeruns_allowed  \
# 2637    93      69               Y  ...         1342              176
# 2667    93      69               Y  ...         1384              195
# 2697   108      54               Y  ...         1305              176
# 2727    84      78               N  ...         1423              215
# 2757    24      36               N  ...          587               98
#
#      walks_allowed  strikeouts_by_pitchers  errors  double_plays  \
# ...

# %% [markdown]
# ## Seleção de linhas e colunas

# %%
df[(df.team_name == 'Boston Red Sox') & (df.year > 2015)].wins
# Out:
# 2637     93
# 2667     93
# 2697    108
# 2727     84
# 2757     24
# Name: wins, dtype: int64

# %%
df[(df.team_name == 'Boston Red Sox') & (df.year > 2015)][['year', 'wins', 'losses']]
# Out:
#       year  wins  losses
# 2637  2016    93      69
# 2667  2017    93      69
# 2697  2018   108      54
# 2727  2019    84      78
# 2757  2020    24      36

# %% [markdown]
# # Proporções

# %%
len(df[ df.year >= 2000 ]) / len(df)
# Out:
# 0.22629310344827586

# %%
len(df[ df.team_name == 'Boston Red Sox' ]) / len(df)
# Out:
# 0.04058908045977012

# %%
df.team_name.value_counts() / len(df)
# Out:
# team_name
# Pittsburgh Pirates       0.046695
# Cincinnati Reds          0.046695
# Philadelphia Phillies    0.046336
# St. Louis Cardinals      0.043463
# Detroit Tigers           0.043103
#                            ...
# St. Louis Perfectos      0.000359
# Milwaukee Grays          0.000359
# Indianapolis Blues       0.000359
# Boston Rustlers          0.000359
# New York Mutuals         0.000359
# Name: count, Length: 86, dtype: float64
